# %%
import numpy as np
import matplotlib.pyplot as plt
import lbg_forecast.nz_sim as nz

# %%
nzs = np.load("./redshifts/emulated_redshifts.npy", allow_pickle=True)
sps_params = np.load("./redshifts/emulated_redshifts_spsparams.npy", allow_pickle=True)
total_nzs = len(nzs)
print("total nzs:", total_nzs)
# Out:
# total nzs: 5

# %%
def plot_multiple_realisations(redshifts, min, max, alpha, density):

    i = min
    while(i <= max):
        nz.visualise_redshifts(redshifts[i], alpha=alpha, density=density)
        i+=1

# %%
plot_multiple_realisations(nzs, 0, 3, alpha=0.25, density=True)

# %%
nz.visualise_redshifts(nzs[0])
