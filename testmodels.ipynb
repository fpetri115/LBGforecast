# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import lbg_forecast.emulator as em
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 2023-11-28 16:19:35.631730: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2023-11-28 16:19:35.631748: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2023-11-28 16:19:35.631759: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2023-11-28 16:19:35.631786: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %%
lossu = np.load("models/loss_lsst_u.npy")
lossg = np.load("models/loss_lsst_g.npy")
lossr = np.load("models/loss_lsst_r.npy")
lossi = np.load("models/loss_lsst_i.npy")
lossz = np.load("models/loss_lsst_z.npy")
lossy = np.load("models/loss_lsst_y.npy")
plt.plot(lossu)
plt.plot(lossg)
plt.plot(lossr)
plt.plot(lossi)
plt.plot(lossz)
plt.plot(lossy)
plt.yscale("log")

# %%
vallossu = np.load("models/valloss_lsst_u.npy")
vallossg = np.load("models/valloss_lsst_g.npy")
vallossr = np.load("models/valloss_lsst_r.npy")
vallossi = np.load("models/valloss_lsst_i.npy")
vallossz = np.load("models/valloss_lsst_z.npy")
vallossy = np.load("models/valloss_lsst_y.npy")
plt.plot(vallossu)
plt.plot(vallossg)
plt.plot(vallossr)
plt.plot(vallossi)
plt.plot(vallossz)
plt.plot(vallossy)

plt.yscale("log")

# %%
lr = np.load("models/lr_lsst_u.npy")
plt.plot(lr)

# %%
#training data
ndata = 1000000
spsparams = np.load("data/data/training_params.npy")[:ndata]
photometry = np.load("data/data/training_data.npy")[:ndata]

# %%
model = em.fsps_emulator()

# %%
model.mimic_photometry(spsparams[100]) - photometry[100][:6]
# Out:
# array([-0.00393652, -0.04720093,  0.00277019, -0.03459608,  0.04462837,
#        -0.01235673])
