# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
lossu = np.load("models/loss_lsst_u.npy")
#lossg = np.load("models/loss_lsst_g.npy")
lossr = np.load("models/loss_lsst_r.npy")
lossi = np.load("models/loss_lsst_i.npy")
lossz = np.load("models/loss_lsst_z.npy")
lossy = np.load("models/loss_lsst_y.npy")
plt.plot(lossu)
#plt.plot(lossg)
plt.plot(lossr)
plt.plot(lossi)
plt.plot(lossz)
plt.plot(lossy)
plt.yscale("log")

# %%
valloss = np.load("models/valloss_lsst_u.npy")
plt.plot(valloss)
plt.yscale("log")

# %%
lr = np.load("models/lr_lsst_u.npy")
plt.plot(lr)
