# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import lbg_forecast.emulator as em
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 2023-11-29 19:23:26.254356: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2023-11-29 19:23:26.254373: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2023-11-29 19:23:26.254403: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2023-11-29 19:23:26.254453: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-11-29 19:23:26.254476: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
lossu = np.load("models/loss_lsst_u.npy")
lossg = np.load("models/loss_lsst_g.npy")
lossr = np.load("models/loss_lsst_r.npy")
lossi = np.load("models/loss_lsst_i.npy")
lossz = np.load("models/loss_lsst_z.npy")
lossy = np.load("models/loss_lsst_y.npy")
plt.plot(lossu)
plt.plot(lossg)
plt.plot(lossr)
plt.plot(lossi)
plt.plot(lossz)
plt.plot(lossy)
plt.yscale("log")

# %%
vallossu = np.load("models/valloss_lsst_u.npy")
vallossg = np.load("models/valloss_lsst_g.npy")
vallossr = np.load("models/valloss_lsst_r.npy")
vallossi = np.load("models/valloss_lsst_i.npy")
vallossz = np.load("models/valloss_lsst_z.npy")
vallossy = np.load("models/valloss_lsst_y.npy")
plt.plot(vallossu)
plt.plot(vallossg)
plt.plot(vallossr)
plt.plot(vallossi)
plt.plot(vallossz)
plt.plot(vallossy)

plt.yscale("log")

# %%
lr = np.load("models/lr_lsst_u.npy")
plt.plot(lr)

# %%
#training data
ndata = 1000000
spsparams = np.load("data/data/training_params.npy")[:ndata]
photometry = np.load("data/data/training_data.npy")[:ndata]

# %%
model = em.fsps_emulator()

# %%
model.mimic_photometry(spsparams[2]) - photometry[2][:6]
# Out:
# array([ 0.04752394, -0.00178277, -0.00917031, -0.02410246, -0.02072941,
#        -0.01431531])
