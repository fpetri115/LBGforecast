# %%
import numpy as np
from nz_model import NzModel
import matplotlib.pyplot as plt
from angular_power import cl_int
from angular_power import cl_lbg
from angular_power import cl_noise
from angular_power import cl_theory
from angular_power import plot_cls

from modified_bias import custom_bias
from angular_power import define_cosmo

# %%
z_space = np.arange(0, 7, 0.01)

# %%
ell = np.arange(100, 1000, 1)

# %%
cbias = custom_bias(1, 2, 1.5)

# %%
plt.plot(cbias(define_cosmo(), z_space))
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
cl = cl_theory(define_cosmo(), 100, 1, 2, ell)

# %%
fig, axes = plt.subplots(3, 3, figsize = (20, 10))
cl_list = np.split(cl, 6)

i = 0
j = 0
k = 0
while(j < 3):
    
    i=0
    while(i < 3):
        if(i >= j):
            ax = axes[i][j]
            ax.plot(cl_list[k])
            k+=1
        i+=1
    j+=1
