# %%
import os
os.environ["SPS_HOME"] = "/Users/fpetri/packages/fsps"

# %%
import numpy as np
import matplotlib.pyplot as plt
import lbg_forecast.hyperparams as hyp
import lbg_forecast.tools as tools

# %%
photometry = np.load("./data/data/generated_photo_final.npy")
spsparams = np.load("./data/data/generated_spsparams.npy")
#hyperparams = np.load("./data/data/hyperparameters.npy", allow_pickle=True)

# %%
tools.plot_galaxy_population(spsparams)

# %%
tools.sfh_zhis_diag(spsparams, 0)
# Out:
# Galaxy Age (Gyr): 0.7081074772728249
# Age of the universe at given redshift (Gyr): 0.9840234535823323
# Redshift: 5.811793689748123
# Observed Metallicity (Absolute Metallicity): 0.006218854676432183
# (array([4.49043428e-05, 4.49043469e-05, 4.49043511e-05, 4.49043554e-05,
#         4.49043598e-05, 4.49043643e-05, 4.49043688e-05, 4.49043734e-05,
#         4.49043780e-05, 4.49043828e-05, 4.49043876e-05, 4.49043926e-05,
#         4.49043976e-05, 4.49044027e-05, 4.49044079e-05, 4.49044131e-05,
#         4.49044185e-05, 4.49044239e-05, 4.49044295e-05, 4.49044351e-05,
#         4.49044409e-05, 4.49044467e-05, 4.49044527e-05, 4.49044587e-05,
#         4.49044648e-05, 4.49044711e-05, 4.49044775e-05, 4.49044839e-05,
#         4.49044905e-05, 4.49044972e-05, 4.49045040e-05, 4.49045109e-05,
#         4.49045180e-05, 4.49045252e-05, 4.49045324e-05, 4.49045399e-05,
#         4.49045474e-05, 4.49045551e-05, 4.49045629e-05, 4.49045708e-05,
# ...
